# %%
# %load_ext autoreload
# %autoreload 2\

# %%
import sys
sys.path.insert(0, '../')
import rhkpy

import matplotlib.pyplot as pl
import numpy as np
import xarray as xr

import hvplot.xarray
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## Iz

# %%
filename_izmap = 'Iz_map_Stripes-9K-HOPG-SPI2-3_2021_09_08_11_21_03_743.sm4'
izmap = rhkpy.rhkdata(filename_izmap)

# %%
spectra_positions = izmap.spectra.isel(zscandir=0, repetitions=0, z=0).hvplot.scatter(x='specpos_x', y='specpos_y', aspect=1)

# %%
spectra_positions
# Out:
# :Scatter   [specpos_x]   (specpos_y)

# %%
izmap.image.topography[:, :, 0].hvplot()
# Out:
# :Image   [y,x]   (topography)

# %%
izmap_abs = izmap.coord_to_absolute()

# %%
izmap_abs.image.topography[:, :, 0].hvplot(cmap = 'viridis', aspect = 1)
# Out:
# :Image   [y,x]   (topography)

# %%
currentmap = izmap.spectra['current'].mean(dim=['repetitions', 'zscandir']).sel(z=0.37, method='nearest').hvplot(
    x='specpos_x',
    y='specpos_y',
    aspect=1,
    cmap='viridis')

# %%
single_spec1 = izmap.spectra['current'].mean(dim=['repetitions', 'zscandir']).sel(specpos_x=-106.57, specpos_y=-87.5, method='nearest').hvplot(x='z', aspect=1)
single_spec2 = izmap.spectra['current'].mean(dim=['repetitions', 'zscandir']).sel(specpos_x=-101.24, specpos_y=-87.27, method='nearest').hvplot(x='z', aspect=1)

# %%
currentmap + single_spec1 * single_spec2
# Out:
# C:\Users\zrbyt\WPy64-31090\python-3.10.9.amd64\lib\site-packages\holoviews\plotting\bokeh\plot.py:987: UserWarning: found multiple competing values for 'toolbar.active_drag' property; using the latest value
#   layout_plot = gridplot(
# C:\Users\zrbyt\WPy64-31090\python-3.10.9.amd64\lib\site-packages\holoviews\plotting\bokeh\plot.py:987: UserWarning: found multiple competing values for 'toolbar.active_scroll' property; using the latest value
#   layout_plot = gridplot(
# :Layout
#    .Image.I   :Image   [specpos_x,specpos_y]   (current)
#    .Overlay.I :Overlay
#       .Curve.I  :Curve   [z]   (current)
#       .Curve.II :Curve   [z]   (current)

# %%
izmap.image.attrs['scan angle']
# Out:
# -10.0

# %%
topo = izmap_abs.image['topography'].isel(scandir=0).hvplot(cmap='bone', aspect=1)

# %%
specpos = izmap.spectra['current'].mean(dim=['zscandir', 'repetitions']).isel(z=0).hvplot.scatter(x='specpos_x', y='specpos_y', aspect=1, marker='x')

# %%
topo * specpos
# Out:
# :Overlay
#    .Image.I   :Image   [y,x]   (topography)
#    .Scatter.I :Scatter   [specpos_x]   (specpos_y)

# %% [markdown]
# # dI/dV

# %%
filename_didumap = 'C:/Users/zrbyt/OneDrive - energia.mta.hu/Documents/work_MFA/lectures - conferences/2023/Kirchberg/poster - stacking faults/intro/ABC_Graphite-Sample5_9K_2021_08_23_02_27_55_533.sm4'
didumap = rhkpy.rhkdata(filename_didumap)

# %%
didumap_norep = didumap.spectra.lia.mean(dim = ['repetitions', 'biasscandir'])

# %%
didumap_norep
# Out:
# <xarray.DataArray 'lia' (bias: 501, specpos_x: 64, specpos_y: 64)>
# array([[[4.06173754, 4.15178246, 4.05647557, ..., 4.35846855,
#          4.36814965, 3.90124039],
#         [3.97061694, 4.30923185, 4.14463922, ..., 3.38203039,
#          4.07123703, 3.47154213],
#         [3.7691253 , 4.06506935, 4.04218908, ..., 3.12878283,
#          3.46078302, 3.78847586],
#         ...,
#         [4.07031735, 4.32435188, 4.16384076, ..., 3.55758236,
#          3.97618392, 3.62967139],
#         [4.81104242, 3.84023411, 4.34514365, ..., 3.38596523,
#          3.14889008, 3.41498757],
#         [4.02664763, 4.24425814, 4.19906804, ..., 3.21695579,
#          3.10580943, 3.39858698]],
#
#        [[4.19785965, 4.21422298, 4.03166979, ..., 4.32468948,
#          4.48908188, 3.99293608],
#         [3.93718013, 4.27447024, 4.0881708 , ..., 3.41177916,
#          4.11086248, 3.72132284],
#         [3.58964314, 4.01964409, 4.12083694, ..., 3.17594267,
#          3.54690009, 3.71395608],
# ...
# ...

# %%
didumap_sel = didumap.spectra.lia.mean(dim = ['repetitions', 'biasscandir'])

# %%
didumap_sel.hvplot(groupby = 'bias', cmap = 'viridis', aspect = 1)
# Out:
# :DynamicMap   [bias]
#    :Image   [specpos_y,specpos_x]   (lia)
